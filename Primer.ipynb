# %%
G = graphs.RandomTree(20)
G.plot()
# Out:
# Graphics object consisting of 40 graphics primitives

# %%
G.add_edge(G.complement().random_edge())
G.plot()
# Out:
# Graphics object consisting of 41 graphics primitives

# %%
H1 = graphs.RandomRegular(2, 20)
H2 = graphs.RandomRegular(2, 20)

# %%
H1.plot()
# Out:
# Graphics object consisting of 41 graphics primitives

# %%
H2.plot()
# Out:
# Graphics object consisting of 41 graphics primitives

# %%
H = H1.union(H2)
H.plot()
# Out:
# Graphics object consisting of 61 graphics primitives

# %%
d = G.distance_all_pairs()
d
# Out:
# {0: {0: 0,
#   1: 6,
#   2: 9,
#   3: 4,
#   4: 5,
#   5: 3,
#   6: 4,
#   7: 3,
#   8: 4,
#   9: 7,
#   10: 3,
#   11: 6,
#   12: 5,
#   13: 8,
#   14: 5,
#   15: 1,
#   16: 9,
#   17: 7,
#   18: 4,
#   19: 2},
#  1: {0: 6,
#   1: 0,
#   2: 3,
#   3: 4,
#   4: 5,
#   5: 3,
#   6: 2,
#   7: 5,
#   8: 4,
#   9: 1,
#   10: 5,
#   11: 6,
#   12: 1,
#   13: 2,
#   14: 3,
#   15: 5,
#   16: 3,
#   17: 1,
#   18: 4,
#   19: 4},
#  2: {0: 9,
#   1: 3,
#   2: 0,
#   3: 7,
#   4: 8,
#   5: 6,
#   6: 5,
#   7: 8,
#   8: 7,
#   9: 2,
#   10: 8,
#   11: 9,
#   12: 4,
#   13: 1,
#   14: 6,
#   15: 8,
#   16: 2,
#   17: 4,
#   18: 7,
#   19: 7},
#  3: {0: 4,
#   1: 4,
#   2: 7,
#   3: 0,
#   4: 3,
#   5: 1,
#   6: 2,
#   7: 3,
#   8: 2,
#   9: 5,
#   10: 3,
#   11: 4,
#   12: 3,
#   13: 6,
#   14: 3,
#   15: 3,
#   16: 7,
#   17: 5,
#   18: 2,
#   19: 2},
#  4: {0: 5,
#   1: 5,
#   2: 8,
#   3: 3,
#   4: 0,
#   5: 2,
#   6: 3,
#   7: 4,
#   8: 1,
#   9: 6,
#   10: 4,
#   11: 1,
#   12: 4,
# ...

# %%
d[2][7]
# Out:
# 8

# %%
import matplotlib
